# %%
# %config Completer.use_jedi = False

# %%
import os
os.chdir('..')

# %%
from tspmodel.iohandler.FileInput import FileInput
from tspmodel.algorithm.TspSolverGreedy import TspSolverGreedy

# %%
tsp = TspSolverGreedy(FileInput('tspmodel/tests/input2.txt').read(), True)

# %%
solution = tsp.solve(tsp.vertices()[0]).solution()

# %%
print(f'{solution:.2f}')
# Out:
# 7.89

# %%
tsp.graph()
# Out:
# <Graph with 4 vertices and 4 edges>
