# %%
# %config Completer.use_jedi = False

# %%
import os
os.chdir('..')

# %%
from tspmodel.graph.DirectedGraph import DirectedGraph
from tspmodel.graph.Vertex import Vertex
from tspmodel.graph.Edge import Edge

# %%
example1 = [
    Vertex(1).set_coordinate(1, 1),
    Vertex(2).set_coordinate(2, 3),
    Vertex(3).set_coordinate(3, 1),
]

G1 = DirectedGraph(visual_mode=True)

for v in example1:
    G1.add_vertex(v)

G1
# Out:
# <Graph with 3 vertices and 0 edges>

# %%
example2 = [
    Vertex(1).set_coordinate(1, 1),
    Vertex(2).set_coordinate(2, 3),
    Vertex(3).set_coordinate(3, 1),
    Vertex(4).set_coordinate(4, 2),
]

G2 = DirectedGraph(visual_mode=True)

for v in example2:
    G2.add_vertex(v)

G2
# Out:
# <Graph with 4 vertices and 0 edges>

# %%
example3 = [
    Vertex(1).set_coordinate(0, 6),
    Vertex(2).set_coordinate(1, 0),
    Vertex(3).set_coordinate(2, 3),
    Vertex(4).set_coordinate(5, 4),
    Vertex(5).set_coordinate(6, 1),
    Vertex(6).set_coordinate(7, 5),
]

G3 = DirectedGraph(visual_mode=True)

for v in example3:
    G3.add_vertex(v)

G3
# Out:
# <Graph with 6 vertices and 0 edges>
